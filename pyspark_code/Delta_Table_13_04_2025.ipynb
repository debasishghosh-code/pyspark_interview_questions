# %% [markdown]
# **Employee data**

# %%
def getSchema():
    from pyspark.sql.types import MapType, StructType, StructField, StringType, IntegerType, ArrayType, DoubleType

    invoice_schema = StructType([
            StructField('InvoiceNumber', StringType(), True),
            StructField('CreatedTime', IntegerType(), True),
            StructField('StoreID', StringType(), True), 
            StructField('CashierID', StringType(), True),
            StructField('CustomerType', StringType(), True),
            StructField('CustomerCardNo', StringType(), True),
            StructField('TotalAmount', DoubleType(), True),
            StructField('NumberOfItems', IntegerType(), True),
            StructField('PaymentMethod', StringType(), True),
            StructField('TaxableAmount', StringType(), True),
            StructField('CGST', DoubleType(), True),
            StructField('SGST', DoubleType(), True),
            StructField('CESS', DoubleType(), True),
            StructField('DeliveryType', StringType(), True),
            StructField('DeliveryAddress', StructType([
                StructField('AddressLine', StringType(), True),
                StructField('City', StringType(), True),
                StructField('State', StringType(), True),
                StructField('PinCode', StringType(), True),
                StructField('ContactNumber', StringType(), True)
            ])),
            StructField('InvoiceLineItems', ArrayType(StructType([
                StructField('ItemCode', StringType(), True),
                StructField('ItemDescription', StringType(), True),
                StructField('ItemPrice', DoubleType(), True),
                StructField('ItemQty', IntegerType(), True),
                StructField('TotalValue', DoubleType(), True)
            ])))
        ])
    return invoice_schema

# %%
emp_df = (spark.read.format('json') 
    #.option('header', 'true') \
    .schema(getSchema())
    .load('dbfs:/FileStore/invoices')
)
display(emp_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNumber</th><th>CreatedTime</th><th>StoreID</th><th>CashierID</th><th>CustomerType</th><th>CustomerCardNo</th><th>TotalAmount</th><th>NumberOfItems</th><th>PaymentMethod</th><th>TaxableAmount</th><th>CGST</th><th>SGST</th><th>CESS</th><th>DeliveryType</th><th>DeliveryAddress</th><th>InvoiceLineItems</th></tr></thead><tbody><tr><td>94201418</td><td>null</td><td>STR7443</td><td>OAS845</td><td>PRIME</td><td>8790333340</td><td>9000.0</td><td>4</td><td>CASH</td><td>9000.0</td><td>225.0</td><td>225.0</td><td>11.25</td><td>HOME-DELIVERY</td><td>List(House No 383, 4427 Pellentesque Rd., Bokaro Steel City, Jharkhand, 509723, 1442202063)</td><td>List(List(258, Closet, 1687.0, 2, 3374.0), List(538, Grandmother clock, 1301.0, 1, 1301.0), List(528, Projection clock, 2365.0, 1, 2365.0), List(673, Dough scraper, 980.0, 2, 1960.0))</td></tr><tr><td>8749479</td><td>null</td><td>STR5864</td><td>OAS287</td><td>PRIME</td><td>7589671731</td><td>7646.0</td><td>4</td><td>CASH</td><td>7646.0</td><td>191.15</td><td>191.15</td><td>9.557500000000001</td><td>HOME-DELIVERY</td><td>List(1852 Est St., Imphal, Manipur, 120023, 6124913142)</td><td>List(List(593, Hanging curtains, 1896.0, 2, 3792.0), List(308, Butterfly chair, 857.0, 2, 1714.0), List(383, Innerspring Mattress, 655.0, 1, 655.0), List(423, Quilt, 1485.0, 1, 1485.0))</td></tr><tr><td>91509413</td><td>null</td><td>STR2629</td><td>OAS737</td><td>NONPRIME</td><td>2461788838</

# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>partition_id</th><th>count</th></tr></thead><tbody><tr><td>0</td><td>590</td></tr><tr><td>1</td><td>501</td></tr><tr><td>2</td><td>500</td></tr><tr><td>3</td><td>10</td></tr></tbody></table></div>

# %%
emp_df=emp_df.repartition(4)

# %%
partition_df=emp_df.withColumn('partition_id',spark_partition_id())
partition_df.show()
# Out:
# +-----------+------------+-------------------+------------+
# |employee_id|entry_detail|   timestamp_detail|partition_id|
# +-----------+------------+-------------------+------------+
# |       1002|       login|2023-06-25 01:00:34|           0|
# |       1004|       login|2023-06-30 01:00:34|           0|
# |       1000|       login|2023-06-16 01:00:34|           0|
# |       1003|       login|2023-06-28 01:00:34|           0|
# |       1000|       login|2023-06-18 01:00:34|           1|
# |       1002|       login|2023-06-24 01:00:34|           1|
# |       1003|      logout|2023-06-29 01:00:34|           1|
# |       1002|      logout|2023-06-26 01:00:34|           1|
# |       1001|      logout|2023-06-23 01:00:34|           2|
# |       1003|       login|2023-06-27 01:00:34|           2|
# |       1004|      logout|2023-07-01 01:00:34|           2|
# |       1001|       login|2023-06-20 01:00:34|           2|
# |       1001|       login|2023-06-21 01:00:34|           3|
# |       1000|      logout|2023-06-17 01:00:34|           3|
# |       1000|      logout|2023-06-19 01:00:34|           3|
# |       1001|       login|2023-06-22 01:00:34|           3|
# +-----------+------------+-------------------+------------+

# %%
display(partition_df.groupBy('partition_id').count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>partition_id</th><th>count</th></tr></thead><tbody><tr><td>0</td><td>4</td></tr><tr><td>1</td><td>4</td></tr><tr><td>2</td><td>4</td></tr><tr><td>3</td><td>4</td></tr></tbody></table></div>

# %%
dbutils.fs.rm("dbfs:/user/hive/warehouse/invoice_delta", recurse=True)
# Out:
# Out[31]: True

# %%
#dbutils.fs.mkdirs("dbfs:/FileStore/SalesDelta")
# Out:
# Out[9]: True

# %%
#create delta table
emp_df.write.format('delta').mode('overwrite').saveAsTable('invoice_delta')

# %%
# %sql

select * from invoice_delta where InvoiceNumber ='51402977'limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNumber</th><th>CreatedTime</th><th>StoreID</th><th>CashierID</th><th>CustomerType</th><th>CustomerCardNo</th><th>TotalAmount</th><th>NumberOfItems</th><th>PaymentMethod</th><th>TaxableAmount</th><th>CGST</th><th>SGST</th><th>CESS</th><th>DeliveryType</th><th>DeliveryAddress</th><th>InvoiceLineItems</th></tr></thead><tbody><tr><td>51402977</td><td>null</td><td>STR7188</td><td>OAS134</td><td>Not PRIME</td><td>4629185211</td><td>11114.0</td><td>4</td><td>CARD</td><td>11114.0</td><td>277.85</td><td>277.85</td><td>13.8925</td><td>TAKEAWAY</td><td>null</td><td>List(List(458, Wine glass, 1644.0, 2, 3288.0), List(283, Portable Lamps, 2236.0, 1, 2236.0), List(498, Carving knifes, 1424.0, 2, 2848.0), List(523, Oil-lamp clock, 1371.0, 2, 2742.0))</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE HISTORY invoice_delta
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>1</td><td>2025-04-13T14:47:40.000+0000</td><td>7937032294484231</td><td>ghdebasish44@gmail.com</td><td>UPDATE</td><td>Map(predicate -> ["(InvoiceNumber#5114 = 51402977)"])</td><td>null</td><td>List(2026787703974052)</td><td>0413-134854-s8xl425w</td><td>0</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 41462, numCopiedRows -> 500, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 4577, scanTimeMs -> 2383, numAddedFiles -> 1, numUpdatedRows -> 1, numAddedBytes -> 41535, rewriteTimeMs -> 2168)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>0</td><td>2025-04-13T14:36:54.000+0000</td><td>7937032294484231</td><td>ghdebasish44@gmail.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(2026787703974052)</td><td>0413-134854-s8xl425w</td><td>null</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 4, numOutputRows -> 1601, numOutputBytes -> 139350)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr></tbody></table></div>

# %%
# %sql
UPDATE invoice_delta
set CustomerType='Not PRIME'
where InvoiceNumber='51402977'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from invoice_delta VERSION AS OF 0
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-2286694977605771>:7
#       5     display(df)
#       6     return df
# ----> 7   _sqldf = ____databricks_percent_sql()
#       8 finally:
#       9   del ____databricks_percent_sql
#
# File <command-2286694977605771>:4, in ____databricks_percent_sql()
#       2 def ____databricks_percent_sql():
#       3   import base64
# ----> 4   df = spark.sql(base64.standard_b64decode("c2VsZWN0ICogZnJvbSBpbnZvaWNlX2RlbHRhIFZFUlNJT04gQVMgT0YgMA==").decode())
#       5   display(df)
#       6   return df
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
#      50         module_name, class_name, function_name, time.perf_counter() - start, signature
#      51     )
#      52     return res
#
# File /databricks/spark/python/pyspark/sql/session.py:1387, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#    1385 try:
#    1386     litArgs = {k: _to_java_column(lit(v)) for k, v in (args or {}).items()}
# -> 1387     return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1388 finally:
#    1389     if len(kwargs) > 0:
#
# File /databricks/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /databricks/spark/python/pyspark/errors/exceptions.py:234, in capture_sql_exception.<locals>.deco(*a, **kw)
#     230 converted = convert_exception(e.java_exception)
#     231 if not isinstance(converted, UnknownException):
#     232     # Hide where the exception came from that shows a non-Pythonic
#     233     # JVM exception message.
# --> 234     raise converted from None
#     235 else:
#     236     raise
#
# AnalysisException: Invalid usage of '*' in Project.; line 1 pos 7;
# 'Project [*]
# +- 'RelationTimeTravel 'UnresolvedRelation [invoice_delta], [], false, 0

# %%
# %sql
RESTORE invoice_delta versiom

# %%
transactions_file = "dbfs:/FileStore/transaction"
df_transactions = spark.read.parquet(transactions_file)
df_transactions.show(5)
# Out:
# +----------+----------+----------+---------------+----------+----+-----+---+-------------+------+-----------+
# |   cust_id|start_date|  end_date|         txn_id|      date|year|month|day| expense_type|   amt|       city|
# +----------+----------+----------+---------------+----------+----+-----+---+-------------+------+-----------+
# |C0YDPQWPBJ|2010-07-01|2018-12-01|TZ5SMKZY9S03OQJ|2018-10-07|2018|   10|  7|Entertainment| 10.42|     boston|
# |C0YDPQWPBJ|2010-07-01|2018-12-01|TYIAPPNU066CJ5R|2016-03-27|2016|    3| 27| Motor/Travel| 44.34|   portland|
# |C0YDPQWPBJ|2010-07-01|2018-12-01|TETSXIK4BLXHJ6W|2011-04-11|2011|    4| 11|Entertainment|  3.18|    chicago|
# |C0YDPQWPBJ|2010-07-01|2018-12-01|TQKL1QFJY3EM8LO|2018-02-22|2018|    2| 22|    Groceries|268.97|los_angeles|
# |C0YDPQWPBJ|2010-07-01|2018-12-01|TYL6DFP09PPXMVB|2010-10-16|2010|   10| 16|Entertainment|  2.66|    chicago|
# +----------+----------+----------+---------------+----------+----+-----+---+-------------+------+-----------+
# only showing top 5 rows

# %%
df_transactions.rdd.getNumPartitions()
# Out:
# Out[5]: 12

# %%
from pyspark.sql.functions import *

display(df_transactions.withColumn('partnid',spark_partition_id()).groupBy('partnid').count().alias('no_of_recs'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>partnid</th><th>count</th></tr></thead><tbody><tr><td>0</td><td>3592625</td></tr><tr><td>1</td><td>3663839</td></tr><tr><td>2</td><td>3454630</td></tr><tr><td>3</td><td>3657055</td></tr><tr><td>4</td><td>3494213</td></tr><tr><td>5</td><td>3408595</td></tr><tr><td>6</td><td>3253507</td></tr><tr><td>7</td><td>3357514</td></tr><tr><td>8</td><td>3129149</td></tr><tr><td>9</td><td>3130443</td></tr><tr><td>10</td><td>3133665</td></tr><tr><td>11</td><td>2514857</td></tr></tbody></table></div>

# %%
df_transactions=df_transactions.repartition(3)

# %%
df_transactions.rdd.getNumPartitions()
# Out:
# Out[8]: 3

# %%
display(df_transactions.withColumn('partnid',spark_partition_id()).groupBy('partnid').count().alias('no_of_recs'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>partnid</th><th>count</th></tr></thead><tbody><tr><td>0</td><td>13263365</td></tr><tr><td>1</td><td>13263363</td></tr><tr><td>2</td><td>13263364</td></tr></tbody></table></div>

# %%
dbutils.fs.mkdirs('dbfs:/FileStore/parquet')
dbutils.fs.mkdirs('dbfs:/FileStore/delta')
# Out:
# Out[10]: True

# %% [markdown]
# **write as parquet file**

# %%
df_transactions.write.format('parquet').mode('overwrite').save('dbfs:/FileStore/parquet')

# %%
display(spark.read.text('dbfs:/FileStore/parquet/part-00000-tid-5947889247407689251-fa9b6987-602f-4d0b-af47-9c5d7383cf99-55-1-c000.snappy.parquet'))
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-1557465436307198>:1
# ----> 1 display(spark.read.text('dbfs:/FileStore/parquet/part-00000-tid-5947889247407689251-fa9b6987-602f-4d0b-af47-9c5d7383cf99-55-1-c000.snappy.parquet'))
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
#      50         module_name, class_name, function_name, time.perf_counter() - start, signature
#      51     )
#      52     return res
#
# File /databricks/spark/python/pyspark/sql/readwriter.py:604, in DataFrameReader.text(self, paths, wholetext, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter)
#     602     paths = [paths]
#     603 assert self._spark._sc._jvm is not None
# --> 604 return self._df(self._jreader.text(self._spark._sc._jvm.PythonUtils.toSeq(paths)))
#
# File /databricks/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /databricks/spark/python/pyspark/errors/exceptions.py:234, in capture_sql_exception.<locals>.deco(*a, **kw)
#     230 converted = convert_exception(e.java_exception)
#     231 if not isinstance(converted, UnknownException):
#     232     # Hide where the exception came from that shows a non-Pythonic
#     233     # JVM exception message.
# --> 234     raise converted from None
#     235 else:
#     236     raise
#
# AnalysisException: [PATH_NOT_FOUND] Path does not exist: dbfs:/FileStore/parquet/part-00000-tid-5947889247407689251-fa9b6987-602f-4d0b-af47-9c5d7383cf99-55-1-c000.snappy.parquet.

# %% [markdown]
# **write as delta file**

# %%
df_transactions.write.format('delta').mode('overwrite').save('dbfs:/FileStore/delta')

# %%
display(spark.read.text('dbfs:/FileStore/delta/_delta_log/00000000000000000001.json'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>{"commitInfo":{"timestamp":1734246400567,"userId":"7937032294484231","userName":"ghdebasish44@gmail.com","operation":"WRITE","operationParameters":{"mode":"Overwrite","partitionBy":"[]"},"notebook":{"notebookId":"2026787703974052"},"clusterId":"1215-062728-jpptlz7n","readVersion":0,"isolationLevel":"WriteSerializable","isBlindAppend":false,"operationMetrics":{"numFiles":"8","numOutputRows":"39790092","numOutputBytes":"1042685587"},"engineInfo":"Databricks-Runtime/12.2.x-scala2.12","txnId":"574b172a-7ca2-49e7-a38d-b303d137f06b"}}</td></tr><tr><td>{"add":{"path":"part-00000-a7b1e053-cae2-4056-a911-26b6ab861029-c000.snappy.parquet","partit
"2010\",\"month\":\"1\",\"day\":\"1\",\"expense_type\":\"Bills and Utilities\",\"amt\":\"0.38\",\"city\":\"boston\"},\"maxValues\":{\"cust_id\":\"CZZS42AMEK\",\"start_date\":\"2014-04-01\",\"end_date\":\"2020-11-01\",\"txn_id\":\"TZZZZYTLNAR40N5\",\"date\":\"2020-12-27\",\"year\":\"2020\",\"month\":\"9\",\"day\":\"9\",\"expense_type\":\"Tax\",\"amt\":\"999.98\",\"city\":\"seattle\"},\"nullCount\":{\"cust_id\":0,\"start_date\":0,\"end_date\":1780722,\"txn_id\":0,\"date\":0,\"year\":0,\"month\":0,\"day\":0,\"expense_type\":0,\"amt\":0,\"city\":0}}","tags":{"INSERTION_TIME":"1734246389000002","MIN_INSERTION_TIME":"1734246389000002","MAX_INSERTION_TIME":"1734246389000002","OPTIMIZE_TARGET_SIZE":"268435456"} ...

# %%
df_transactions=df_transactions.repartition(8)

# %%
df_transactions.write.format('delta').mode('overwrite').save('dbfs:/FileStore/delta')

# %%
#dbutils.fs.rm("dbfs:/FileStore/customers.parquet",True)
# Out:
# Out[18]: True

# %%
df_transactions=df_transactions.limit(2000)
df_transactions.show()
# Out:
# +----------+----------+----------+---------------+----------+----+-----+---+-------------------+------+-------------+
# |   cust_id|start_date|  end_date|         txn_id|      date|year|month|day|       expense_type|   amt|         city|
# +----------+----------+----------+---------------+----------+----+-----+---+-------------------+------+-------------+
# |CGITEKW8I0|2010-11-01|2018-03-01|TLL89MHZOLJ3PV5|2014-10-13|2014|   10| 13|           Gambling| 33.32|      seattle|
# |C0YDPQWPBJ|2010-12-01|2020-09-01|TWZ4AJFU74WDVC8|2017-09-22|2017|    9| 22|           Clothing|224.31|      seattle|
# |C0YDPQWPBJ|2010-10-01|2019-04-01|TR7K1YEO88HDY1W|2015-11-04|2015|   11|  4|      Entertainment| 71.02|     new_york|
# |CP665RP38K|2011-08-01|2019-12-01|TC81VTL94WOFOO5|2013-12-05|2013|   12|  5|           Clothing|103.06|     portland|
# |CGAO9TU7LZ|2012-12-01|      null|TZKI8PPWPZEN4W3|2019-09-07|2019|    9|  7|      Entertainment|  7.63|    san_diego|
# |C0YDPQWPBJ|2010-07-01|2019-06-01|T5ZOKQL23X59QI8|2017-04-23|2017|    4| 23|           Clothing|144.37|      chicago|
# |CR61S59348|2012-05-01|      null|TMUP86IP9CXDH05|2018-07-21|2018|    7| 21|       Motor/Travel| 96.83|       denver|
# |CQU9LG15ON|2013-05-01|      null|TU8KQC16YL1012Q|2013-09-14|2013|    9| 14|      Entertainment|  7.42|     new_york|
# |CGEZPMDN6H|2010-12-01|2018-09-01|TPVNBJ79AJ2MY1V|2014-01-14|2014|    1| 14|           Gambling|114.89|    san_diego|
# |C0YDPQWPBJ|2012-02-01|2020-08-01|TB49LOEPZ1TRAB4|2013-03-01|2013|    3|  1|          Groceries| 67.98|    san_diego|
# |C0YDPQWPBJ|2012-07-01|      null|T3SBQ0TZYV48KN5|2014-09-23|2014|    9| 23|          Groceries|122.67|      chicago|
# |C0YDPQWPBJ|2012-05-01|      null|T64MYY7VD6GWGKO|2020-06-05|2020|    6|  5|Bills and Utilities| 87.62|san_francisco|
# |C0YDPQWPBJ|2011-07-01|      null|T3K6YDVQIW07WMI|2013-03-20|2013|    3| 20|      Entertainment| 37.16|       denver|
# |C0CZCC9UCH|2011-12-01|2019-03-01|TTU5VP07BG1OO6Y|2015-09-17|2015|    9| 17|          Education| 49.76|  los_angeles|
# |C0YDPQWPBJ|2012-07-01|      null|T8O0LKCFL519K7H|2013-07-03|2013|    7|  3|      Entertainment| 11.49|san_francisco|
# |CAWJT264JL|2010-03-01|2018-01-01|TPYB2R4V84IMO70|2012-12-24|2012|   12| 24|      Entertainment| 27.53|san_francisco|
# |CYXX1NBIKL|2012-03-01|2020-07-01|T0DXT5AWJ2I9FBW|2015-02-04|2015|    2|  4|           Clothing|221.23|     portland|
# |C9988TCD70|2010-03-01|2018-05-01|TSOLEAH7KOU8PK8|2015-07-18|2015|    7| 18|      Entertainment| 41.56|    san_diego|
# |C3GRHXTGKN|2013-02-01|      null|TEYOL0V27YKJCKN|2014-05-02|2014|    5|  2|      Entertainment|  5.35|  los_angeles|
# |C0YDPQWPBJ|2012-10-01|      null|TQ3YFDD5L59RTZU|2019-09-13|2019|    9| 13|      Entertainment| 10.63|     new_york|
# +----------+----------+----------+---------------+----------+----+-----+---+-------------------+------+-------------+
# only showing top 20 rows

# %%
df_transactions.write.format('delta').mode('overwrite').save('dbfs:/FileStore/delta')

# %%
df_transactions.rdd.getNumPartitions()
# Out:
# Out[21]: 1

# %%
display(spark.read.text('dbfs:/user/hive/warehouse/transaction_db.db/transtable/_delta_log/00000000000000000000.json'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>{"commitInfo":{"timestamp":1734330911205,"userId":"7937032294484231","userName":"ghdebasish44@gmail.com","operation":"CREATE OR REPLACE TABLE AS SELECT","operationParameters":{"isManaged":"true","description":null,"partitionBy":"[]","properties":"{}"},"notebook":{"notebookId":"2026787703974052"},"clusterId":"1216-045718-rfwode6u","isolationLevel":"WriteSerializable","isBlindAppend":false,"operationMetrics":{"numFiles":"10","numOutputRows":"2000","numOutputBytes":"114122"},"engineInfo":"Databricks-Runtime/12.2.x-scala2.12","txnId":"dd2524fb-4597-4e7a-9af1-7bc7da5ade9d"}}</td></tr><tr><td>{"protocol":{"minReaderVersion":1,"minWriterVersion":2}}</td></tr><tr><td>{"metaData":{"id":"5fd0fb45-989d-4878-823a-46943711dd78","format":{"provider":"parquet","options":{}},"schemaString":"{\"type\":\"struct\",\"fields\":[{\"name\":\"cust_id\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"start_date\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"end_date\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"txn_id\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"date\
# %%
df_transactions=df_transactions.repartition('year')
df_transactions.rdd.getNumPartitions()
#df_transactions.write.format('delta').mode('overwrite').save('dbfs:/FileStore/delta')
# Out:
# Out[35]: 1

# %%
df_transactions.write.format('delta').mode('overwrite').save('dbfs:/FileStore/delta')

# %%
df1=spark.read.format('delta').load('dbfs:/FileStore/delta')

# %%
display(df1.select('year').distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th></tr></thead><tbody><tr><td>2016</td></tr><tr><td>2020</td></tr><tr><td>2012</td></tr><tr><td>2019</td></tr><tr><td>2017</td></tr><tr><td>2014</td></tr><tr><td>2013</td></tr><tr><td>2018</td></tr><tr><td>2011</td></tr><tr><td>2015</td></tr><tr><td>2010</td></tr></tbody></table></div>

# %%
spark.conf.get("spark.sql.adaptive.enabled")
# Out:
# Out[66]: 'false'

# %%
spark.conf.set("spark.sql.adaptive.enabled",False)

# %%
df_transactions=df_transactions.repartition('year')
df_transactions.rdd.getNumPartitions()
# Out:
# Out[67]: 200

# %%
# %sql
CREATE  DATABASE TRANSACTION_DB
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-4156791937332809>:7
#       5     display(df)
#       6     return df
# ----> 7   _sqldf = ____databricks_percent_sql()
#       8 finally:
#       9   del ____databricks_percent_sql
#
# File <command-4156791937332809>:4, in ____databricks_percent_sql()
#       2 def ____databricks_percent_sql():
#       3   import base64
# ----> 4   df = spark.sql(base64.standard_b64decode("Q1JFQVRFIE9SIFJFUExBQ0UgREFUQUJBU0UgVFJBTlNBQ1RJT05fREI=").decode())
#       5   display(df)
#       6   return df
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
#      50         module_name, class_name, function_name, time.perf_counter() - start, signature
#      51     )
#      52     return res
#
# File /databricks/spark/python/pyspark/sql/session.py:1387, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#    1385 try:
#    1386     litArgs = {k: _to_java_column(lit(v)) for k, v in (args or {}).items()}
# -> 1387     return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1388 finally:
#    1389     if len(kwargs) > 0:
#
# File /databricks/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /databricks/spark/python/pyspark/errors/exceptions.py:234, in capture_sql_exception.<locals>.deco(*a, **kw)
#     230 converted = convert_exception(e.java_exception)
#     231 if not isinstance(converted, UnknownException):
#     232     # Hide where the exception came from that shows a non-Pythonic
#     233     # JVM exception message.
# --> 234     raise converted from None
#     235 else:
#     236     raise
#
# AnalysisException: [SCHEMA_ALREADY_EXISTS] Cannot create schema `TRANSACTION_DB` because it already exists.
# Choose a different name, drop the existing schema, or add the IF NOT EXISTS clause to tolerate pre-existing schema.

# %%
# %sql
CREATE  table IF NOT EXISTS TRANSACTION_DB.trans
--drop table TRANSACTION_DB.trans
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from TRANSACTION_DB.trans;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-4156791937332813>:7
#       5     display(df)
#       6     return df
# ----> 7   _sqldf = ____databricks_percent_sql()
#       8 finally:
#       9   del ____databricks_percent_sql
#
# File <command-4156791937332813>:5, in ____databricks_percent_sql()
#       3 import base64
#       4 df = spark.sql(base64.standard_b64decode("c2VsZWN0ICogZnJvbSBUUkFOU0FDVElPTl9EQi50cmFucw==").decode())
# ----> 5 display(df)
#       6 return df
#
# File /databricks/python_shell/dbruntime/display.py:83, in Display.display(self, input, *args, **kwargs)
#      80         if kwargs.get('trigger'):
#      81             raise Exception('Triggers can only be set for streaming queries.')
# ---> 83         self.add_custom_display_data("table", input._jdf)
#      85 elif isinstance(input, list):
#      86     self.display(self.sparkSession.createDataFrame(input))
#
# File /databricks/python_shell/dbruntime/display.py:36, in Display.add_custom_display_data(self, data_type, data)
#      34 def add_custom_display_data(self, data_type, data):
#      35     custom_display_key = str(uuid.uuid4())
# ---> 36     return_code = self.entry_point.addCustomDisplayData(custom_display_key, data_type, data)
#      37     ip_display({
#      38         "application/vnd.databricks.v1+display": custom_display_key,
#      39         "text/plain": "<Databricks Output (not supported in output widgets)>"
#      40     },
#      41                raw=True)
#      42     if return_code == 1:
#
# File /databricks/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /databricks/spark/python/pyspark/errors/exceptions.py:234, in capture_sql_exception.<locals>.deco(*a, **kw)
#     230 converted = convert_exception(e.java_exception)
#     231 if not isinstance(converted, UnknownException):
#     232     # Hide where the exception came from that shows a non-Pythonic
#     233     # JVM exception message.
# --> 234     raise converted from None
#     235 else:
#     236     raise
#
# AnalysisException: You are trying to read a Delta table `spark_catalog`.`transaction_db`.`trans` that does not have any columns.
#
# Write some new data with the option `mergeSchema = true` to be able to read the table.

# %%
(df_transactions.write.format('delta').mode('overwrite').saveAsTable('TRANSACTION_DB.transtable')
 #repartition('year')
)

# %%
# %sql
select * from TRANSACTION_DB.transtable limit 100;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>181</td></tr></tbody></table></div>

# %% [markdown]
# ##SCD1

# %%
customerChangedJson='[\
    {"id":"4","name":"Deb Ryan","address":"st ##21 GRT"},\
    {"id":"3","name":"Magee Cash","address":"po box ##98 Sclala Road 12"}\
]'

# %%
customerChangedDF=spark.read.json(sc.parallelize([customerChangedJson]))
customerChangedDF.show()

# %%
customerChangedDF.write.mode("overwrite").format('delta').saveAsTable('customer.customer_data_changed')

# %%
# %sql
MERGE INTO customer.customer_data C1
USING customer.customer_data_changed C2
ON C1.id=C2.id
  WHEN MATCHED THEN
    UPDATE SET C1.name=C2.name,
                C1.address=C2.address
  WHEN NOT MATCHED THEN
    INSERT *

# %%
# %sql
select * from customer.customer_data

# %%
# %sql
DESCRIBE HISTORY customer.customer_data

# %%
# %sql
describe extended customer.customer_data

# %%
# from delta.tables import DeltaTable

# #deltaTable=DeltaTable.forPath(spark,'customer.customer_data')

# %% [markdown]
# ##SCD2

# %%
customerJson1='[\
    {"id":"1","name":"Julie Rich","address":"pp #255 Richmond Rd","ingest_date":"2022-03-24"},\
    {"id":"2","name":"Eden Byrd","address":"ag #315 Lexing Rd","ingest_date":"2021-05-14"},\
    {"id":"3","name":"Magee Cash","address":"po box ##33 Vel avn.","ingest_date":"2007-03-09"}\
]'

# %%
customerChangedJson1='[\
    {"id":"4","name":"Deb Ryan","address":"st ##21 GRT","ingest_date":"2001-03-29"},\
    {"id":"3","name":"Magee Cash","address":"po box ##98 Sclala Road 12","ingest_date":"2022-03-24"}\
]'

# %%
customerDF1=spark.read.json(sc.parallelize([customerJson1]))
customerDF1.show(truncate=False)

# %%
from pyspark.sql.functions import lit

customerDF1=customerDF1.withColumn('end_date',lit(''))\
                        .withColumn('status',lit('Current'))\
                            .withColumnRenamed('ingest_date','start_date')
                        
customerDF1.show()

# %%
customerDF1.write.mode('overwrite').format('delta').option("overwriteSchema", "true").saveAsTable('customer.customer_data_scd2')

# %%
customerChangedDF1=spark.read.json(sc.parallelize([customerChangedJson1]))
customerChangedDF1.show(truncate=False)

# %%
customerChangedDF1.write.mode('overwrite').format('delta').saveAsTable('customer.customer_changed_scd2')

# %%
# %sql
select * from customer.customer_data_scd2

# %%
# %sql
select * from customer.customer_changed_scd2

# %%
# %sql
 SELECT  
    a.id as MergeKey,a.id,
    a.address,a.name,a.ingest_date as start_date,
    'Current' as status,
    '' as end_date
    from customer.customer_changed_scd2 a
    UNION ALL
    SELECT  
        null as MergeKey,b.id,
        b.address,b.name,b.ingest_date as start_date,
        'Current' as status,
        '' as end_date
    from customer.customer_changed_scd2 b

# %%
# %sql
select * from customer.customer_data_scd2

# %% [markdown]
# ####Merge

# %%
# %sql

MERGE INTO customer.customer_data_scd2 as updt
USING (
    SELECT  
    a.id as MergeKey,a.id,
    a.address,a.name,a.ingest_date as start_date,
    'Current' as status,
    '' as end_date
    from customer.customer_changed_scd2 a
    UNION ALL
    SELECT  
        null as MergeKey,b.id,
        b.address,b.name,b.ingest_date as start_date,
        'Current' as status,
        '' as end_date
    from customer.customer_changed_scd2 b
) src
ON updt.id=src.MergeKey
WHEN MATCHED 
THEN
      UPDATE SET updt.status='Expired',
            updt.end_date=src.start_date
WHEN NOT MATCHED 
THEN
      INSERT *

# %%
# %sql
select * from customer.customer_data_scd2
